# %% [markdown]
# # 🔙 4.2 Backtracking Concept
#
# Backtracking tries to build a solution step by step.
#
# If a partial solution cannot work, we **go back** and try another path.

# %% [markdown]
# Typical uses:
#
# - Puzzles (Sudoku, N-Queens)
# - Generating combinations or permutations
# - Path finding in some search spaces
