# %% [markdown]
# # 5.1 Introduction to Greedy Algorithms
#
# Greedy algorithms build a solution step by step, always taking the **best local choice** at each step.
#
# Sometimes this also gives the best overall solution, but not always.
