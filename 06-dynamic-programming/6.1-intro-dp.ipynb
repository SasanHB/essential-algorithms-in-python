# %% [markdown]
# # 6.1 Introduction to Dynamic Programming
#
# Dynamic programming (DP) is used when:
#
# - Subproblems repeat (overlapping subproblems)
# - The best solution can be built from best sub-solutions (optimal substructure)
#
# We store results of subproblems instead of recomputing them.
