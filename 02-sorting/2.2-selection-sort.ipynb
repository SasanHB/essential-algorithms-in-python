# %% [markdown]
# # 2.2 Selection Sort
#
# Selection sort finds the smallest element and moves it to the front, then repeats.

# %%
def selection_sort(lst):
    '''Sort the list in place using selection sort.

    The algorithm repeatedly selects the smallest remaining element
    and places it at the next position. It is simple but runs in O(n^2)
    time and is not stable.
    '''
    n = len(lst)
    for i in range(n):
        # Assume the smallest value is at position i
        min_index = i
        # Find the index of the smallest element in the remaining unsorted part
        for j in range(i + 1, n):
            if lst[j] < lst[min_index]:
                min_index = j
        # Swap the found minimum element with the first unsorted element
        lst[i], lst[min_index] = lst[min_index], lst[i]

data = [64, 25, 12, 22, 11]
selection_sort(data)
print(data)

# %% [markdown]
# Time complexity: **O(n²)**.

# %% [markdown]
# ### Why Learn Selection Sort?
#
# Selection sort repeatedly picks the smallest item and moves it to the
# front.  This simplicity makes it a good algorithm for learning and for
# situations where memory writes are expensive; it performs a minimal number
# of swaps.  In some low‑resource environments, such as embedded systems, a
# simple in‑place algorithm like selection sort can be easier to implement.
#
# ### Try it yourself
#
# Write your own version of selection sort and count how many times it swaps
# elements.  Try it on a small list of numbers or names.  How does the
# number of swaps compare to bubble sort?
